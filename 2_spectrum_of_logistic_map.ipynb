# %% [markdown]
# ## 2. Spectrum of Logistic Map

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### a)

# %%
def logistic_map(mu, u):
    return mu * u * (1 - u)

def logistic_seq(mu, u0=.1, n=10, windup=0):
    u = u0
    for i in range(windup):
        u = logistic_map(mu, u)
    out = []
    for i in range(n):
        u = logistic_map(mu, u)
        out.append(u)
    return(out)

# %% [markdown]
# #### i)

# %%
mus = [3.3, 3.5, 3.56, 3.57, 3.826, 3.83, 3.8494]
u0 = .1
windup = 1000
iters = 2**12

# %%
sequences = {}
for mu in mus:
    sequences[mu] = logistic_seq(mu, u0, iters, windup)

# %%
for mu, seq in sequences.items():
    plt.plot(seq, linestyle='none', marker='.', markersize=1, label=mu)
plt.legend()

# %% [markdown]
# #### ii)

# %%
spectra = {}
for mu, seq in sequences.items():
    spec = np.fft.rfft(seq)
    spectra[mu] = np.abs(spec)**2

# %%
for mu, spec in spectra.items():
    plt.plot(spec, label=mu)
plt.legend()

# %% [markdown]
# #### iii)

# %%
mus = 3.83
u0 = .1
windup = 1000
iters = 3 * 2**12

# %%
seq = logistic_seq(mu, u0, iters, windup)
spec = np.fft.rfft(np.abs(seq))**2

# %%
plt.plot(spectra[3.83])
plt.plot(spec)

# %% [markdown]
# ### b)
